# %%
#Characteristics
#ordered collection
t=(2,4,6,[1,2,5,8],7)
print(t)
# Out:
# (2, 4, 6, [1, 2, 5, 8], 7)

# %%
#immutable
#After operation it doesn't change the length of object and doesn't change the remaining element position
t=(2,4,6,[1,2,5,8],7)
t[3].append(100)
print(t)
# Out:
# (2, 4, 6, [1, 2, 5, 8, 100], 7)

# %%
#empty tuple representation
#single element representation
t1=(10)
t2=(10,)
t3=tuple()
print(type(t1),type(t2),type(t3))
# Out:
# <class 'int'> <class 'tuple'> <class 'tuple'>

# %%
#Tuple operations
#Tuple concatination
#tuple Repetation

# %%
#Methods
  #index()
  #count()
